# %%
import pandas as pd

PATH = "../data/teacher.jsonl"
df = pd.read_json(PATH, orient="records", lines=True)

# %%
list(
    reversed(
        sorted(
            df.loc[:, "knowsAbout"].explode().dropna().map(lambda x: x["name"]), key=len
        )
    )
)
# Out:
# ['Contact Zone of Popular Culture and International Education',
#  'Transnational Mobility of Asian Students in Asia',
#  'Oligo(2,5-dialkoxy-phenylene-1,4-vinylene)s',
#  'Snowfall on the Japan Sea side of Japan',
#  'Acyclic Diene Metathesis Polymerization',
#  'End-functionalized conjugated polymers',
#  'Simultaneous Localization and Mapping',
#  'Resting State Functional Connectivity',
#  'Monoaminergic regulation of behavior',
#  'Integrated tourist behavior modeling',
#  'Performance measurement information',
#  'Performance measurement innovations',
#  'Estuarine hydro- and morphodynamics',
#  'Behavioral and Systems Neuroscience',
#  'Interactive Modular Screen Systems',
#  "Inhibitors of Alzheimer's Disease",
#  'Long term morphodynamic evolution',
#  'functional connectivity analysis',
#  'asymmetric partitioning of mRNA',
#  'Cloud-precipitation climatology',
#  'Unregulated disclosure settings',
#  'abstract structure of sentences',
#  'High background radiation area',
# ...
