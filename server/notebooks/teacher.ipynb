# %%
import pandas as pd

PATH = "../data/teacher.jsonl"
df = pd.read_json(PATH, orient="records", lines=True)

# %%
list(reversed(sorted(df.loc[:, "knowsAbout"].explode().map(str).unique(), key=len)))
# Out:
# ['Acyclic Diene Metathesis Polymerization',
#  'Education for sustainable development',
#  'Resting State Functional Connectivity',
#  'Integrated tourist behavior modeling',
#  'Feedback of performance measurement',
#  'Estuarine hydro- and morphodynamics',
#  'Behavioral and Systems Neuroscience',
#  'functional connectivity analysis',
#  'asymmetric partitioning of mRNA',
#  'unregulated disclosure settings',
#  'High background radiation area',
#  'coarse Baum-Connes conjecture',
#  'Artificial intelligence (AI)',
#  'Oligonucleotide Therapeutics',
#  'ocean-atmosphere interaction',
#  'cross-cultural communication',
#  'Normally Developing Children',
#  'arctic and subarctic regions',
#  'Big data analysis in tourism',
#  'drosophila model of disease',
#  'Just-in-Time (JIT) compiler',
#  'α-ray spectrum survey meter',
#  '大電力パルスマグネトロンスパッタリング(HIPIMS)',
#  'land-atmosphere interaction',
#  'international communication',
#  'Concept Formation Mechanism',
# ...
